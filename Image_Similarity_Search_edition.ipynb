# %% [markdown]
# # Image Similarity Search

# %% [markdown]
# ### Import Required Libraries

# %%
# import some require library
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision import transforms
import torch
import torch.nn as nn
import torchvision.models as models
from torch.autograd import Variable
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.utils.data import DataLoader, random_split

import os
os.environ['SSL_CERT_FILE'] = '/etc/ssl/certs/ca-certificates.crt'

import ssl
ssl._create_default_https_context = ssl._create_unverified_context


from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Customize Image Dataset

# %%
class CustomImageDataset(Dataset):
    
    def __init__(self, root_dir, transform=None, include_feature_vector=True):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.image_list = self._generate_image_list()
        self.include_feature_vector = include_feature_vector

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        label, img_path = self.image_list[idx]

        # Use PIL to open the image
        image = Image.open(img_path).convert('RGB')

        image_name = os.path.basename(os.path.dirname(img_path))  # Get subcategory name
        # label = class_name  # The category name is the label

        if self.transform:
            image = self.transform(image)

        feature_vector = np.array([[1, 1, 1]])
        if self.include_feature_vector:
            # Load the pre-computed vector from the corresponding .npy file
            vector_name = f'{os.path.splitext(os.path.basename(img_path))[0]}_vector.npy'
            vector_path = os.path.join(os.path.dirname(img_path), vector_name)
            feature_vector = np.load(vector_path)

        return label, image, image_name, feature_vector

    def _generate_image_list(self):
        image_list = []
        for class_name in self.classes:
            class_path = os.path.join(self.root_dir, class_name)
            for root, _, files in os.walk(class_path):
                for file in files:
                    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                        image_list.append((class_name, os.path.join(root, file)))
        return image_list
    
    def process_images_and_save_vectors(self, get_vector_func):
        for idx in range(len(self)):
            label, _, _, _ = self.__getitem__(idx)  # Use __getitem__ method to get label and image path
            img_path = self.image_list[idx][1]  # Extract image path from image_list
            print(img_path)
            image_feature = get_vector_func(img_path)
            # Save the image feature vector in the same directory with .npy extension
            save_path = os.path.splitext(img_path)[0] + '_vector.npy'
            np.save(save_path, image_feature)

# %% [markdown]
# ### Basic Image Preprocessing

# %%
# Additional transformations for data augmentation
random_rotation = transforms.RandomRotation(degrees=10)
color_jitter = transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)
vertical_flip = transforms.RandomVerticalFlip(p=0.5)
zoom = transforms.RandomAffine(degrees=0, scale=(0.8, 1.2))

# Update the image_transform pipeline
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    random_rotation,
    color_jitter,
    transforms.RandomHorizontalFlip(),
    vertical_flip,
    zoom,
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ### Dataset & DataLoader

# %%
# Define the dataset
image_directory = 'Fashion_Products/'  # Replace with the actual directory path
custom_dataset = CustomImageDataset(root_dir=image_directory, transform=image_transform, include_feature_vector=False)

# %%
dataset_size = len(custom_dataset)
train_size = int(0.8 * dataset_size)
test_size = int(0.2*dataset_size)
val_size = dataset_size - train_size - test_size

train_dataset, val_dataset, test_dataset = random_split(custom_dataset, [train_size, val_size, test_size])


# Define DataLoader for training and validation
batch_size = 32

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Data Exploration

# %%
# Now let's plot some random images
def show_images_with_grid(images, labels, num_images=3):
    fig, axes = plt.subplots(2, num_images, figsize=(15, 7))

    for i in range(num_images):
        image = images[i].permute(1, 2, 0)  # Convert from (C, H, W) to (H, W, C) for displaying with matplotlib
        label = labels[i]

        axes[0, i].imshow(image)
        axes[0, i].set_title(f"Label: {label} \n Image Size : {image.size()}")
        axes[0, i].axis('off')

        # Display pixel grid
        axes[1, i].imshow(images[i][0], cmap='gray')  # Assuming images are in grayscale
        axes[1, i].set_title("Pixel Grid")
        axes[1, i].axis('on')

    plt.tight_layout()
    plt.show()

# Get a batch from the DataLoader
for labels, images,_,_ in train_loader:
    # Show the first 5 images along with their labels and pixel grids
    show_images_with_grid(images, labels, num_images=3)
    break  # Break after showing the first batch
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Load Pretrained Model

# %%
# Load the pretrained model
model = models.resnet18(pretrained=True)

# Use the model object to select the desired layer
feature_extractor = torch.nn.Sequential(*list(model.children())[:-1])

# Set model to evaluation mode
model.eval()

# Image transforms
scaler = transforms.Resize((224, 224))
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
to_tensor = transforms.ToTensor()
# Out:
# c:\Users\kimh1\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\kimh1\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### Define a function for image embedding and feature extraction

# %%
def get_vector(image_name):
    # 1. Load the image with Pillow library
    img = Image.open(image_name)
    # 2. Create a PyTorch Variable with the transformed image
    t_img = Variable(normalize(to_tensor(scaler(img))).unsqueeze(0))

    # 3. Move the input to the same device as the model
    device = next(model.parameters()).device
    t_img = t_img.to(device)

    # 4. Set model to evaluation mode
    model.eval()

    # 5. Create a vector of zeros that will hold our feature vector
    #    The 'avgpool' layer has an output size of 512
    my_embedding = torch.zeros(512)

    # 6. Define a function that will copy the output of a layer
    def copy_data(m, i, o):
        my_embedding.copy_(o.data.reshape(o.data.size(1)))

    # 7. Attach that function to our selected layer
    h = layer.register_forward_hook(copy_data)

    # 8. Run the model on our transformed image
    with torch.no_grad():
        model(t_img)

    # 9. Detach our copy function from the layer
    h.remove()

    # 10. Return the feature vector
    return my_embedding.numpy()

# %% [markdown]
# ### Now Let's convert each images to vector representation

# %%
# Call function process_images_and_save_vectors
custom_dataset.process_images_and_save_vectors(get_vector)
print('\nDone')
# Out:
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group101.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group102.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group103.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group104.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group105.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group106.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group107.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group108.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group109.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group110.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group111.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group112.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group113.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group114.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group115.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group116.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group117.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group118.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group119.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group120.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group121.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group122.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group123.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group124.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group125.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group126.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group127.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group128.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group129.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group130.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group131.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group132.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group133.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group134.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group135.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group136.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group137.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group138.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group139.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group140.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group141.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group142.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group143.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group144.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group145.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group146.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group147.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group148.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group149.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group150.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group151.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group152.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group153.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group154.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group155.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group156.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group157.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group158.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group159.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group160.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group161.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group162.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group163.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group164.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group165.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group166.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group167.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group168.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group169.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group201.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group202.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group203.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group204.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group205.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group206.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group207.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group208.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group209.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group210.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group211.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group212.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group213.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group214.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group215.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group216.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group217.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group218.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group219.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group220.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group221.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group222.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group223.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group224.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group225.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group226.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group227.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group228.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group229.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group230.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group231.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group232.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group233.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group234.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group235.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group236.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group237.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group238.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group239.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group240.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group241.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group242.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group243.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group244.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group245.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group246.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group247.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group248.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group249.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group250.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group251.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group252.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group253.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group254.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group255.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group256.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group257.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group258.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group259.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group260.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group261.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group262.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group263.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group264.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group265.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group266.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group267.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group268.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group301.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group302.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group303.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group304.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group305.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group306.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group307.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group308.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group309.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group310.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group311.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group312.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group313.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group314.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group315.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group316.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group317.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group318.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group319.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group320.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group321.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group322.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group323.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group324.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group325.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group326.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group327.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group328.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group329.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group330.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group331.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group332.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group333.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group334.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group335.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group336.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group337.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group338.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group339.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group340.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group341.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group342.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group343.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group344.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group345.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group346.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group347.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group348.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group349.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group350.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group351.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group352.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group353.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group354.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group355.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group356.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group357.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group358.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group359.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group360.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group361.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group362.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group363.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group364.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group401.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group402.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group403.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group404.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group405.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group406.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group407.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group408.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group409.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group410.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group411.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group412.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group413.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group414.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group415.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group416.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group417.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group418.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group419.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group420.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group421.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group422.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group423.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group424.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group425.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group426.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group427.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group428.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group429.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group430.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group431.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group432.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group433.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group434.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group435.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group436.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group437.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group438.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group439.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group440.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group441.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group442.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group443.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group444.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group445.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group446.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group447.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group448.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group449.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group450.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group451.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group452.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group453.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group454.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group455.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group456.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group457.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group458.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group459.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group460.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group461.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group462.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group463.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group464.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group465.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group466.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group468.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group469.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group470.jpeg
# Fashion_Product_Dataset/Backpacks\NordStrom_Backpack\NordStrom_Backpack_Group471.jpeg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks01.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks02.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks03.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks04.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks05.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks06.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks07.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks09.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks10.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks11.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks12.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks13.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks14.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks15.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks16.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks17.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks18.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks19.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks20.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks21.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks22.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks23.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks24.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks25.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks26.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks27.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks28.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks29.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks30.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks31.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks32.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks33.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks34.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks35.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks36.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks37.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks38.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks39.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks40.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks41.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks42.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks43.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks44.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks57.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks58.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks59.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks60.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks61.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks62.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks63.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks64.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks65.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks66.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks67.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks68.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks69.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks70.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks71.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks72.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group1_Bagpacks73.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks01.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks02.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks03.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks04.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks05.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks06.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks07.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks08.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks09.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks10.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks11.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks12.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks13.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks14.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks15.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks16.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks17.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks18.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks19.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks20.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks21.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks22.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks23.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks24.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks25.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks26.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks27.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks28.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks29.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks30.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks31.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks32.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks33.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks34.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks35.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks36.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks37.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks38.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks40.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks41.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks42.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks43.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks56.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks57.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks58.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks59.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks60.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks61.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks62.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks63.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks64.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks65.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks66.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks67.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks68.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks69.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks70.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks71.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group2_Backpacks72.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks01.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks02.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks03.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks04.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks05.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks06.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks07.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks08.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks09.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks10.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks11.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks12.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks13.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks14.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks15.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks16.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks17.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks18.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks19.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks20.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks21.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks22.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks23.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks24.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks25.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks26.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks27.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks28.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks29.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks30.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks31.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks32.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks33.jpg
# Fashion_Product_Dataset/Backpacks\Zumiez_Backpacks\Zumiez_Group3_Backpacks34.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses01.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses02.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses04.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses05.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses06.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses07.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses08.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses09.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses10.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses11.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses12.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses13.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses14.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses15.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses16.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses17.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses18.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses19.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses20.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses21.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses22.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses23.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses24.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses25.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses26.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses27.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses28.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses29.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses30.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses31.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses32.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses33.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses34.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses35.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses36.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses37.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses38.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses39.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses40.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses41.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses42.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses43.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses44.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses45.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses46.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses47.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses48.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses49.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses50.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses51.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses52.jpg
# Fashion_Product_Dataset/Dresses\ARKET_Dresses\ARKET_Dresses53.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress013.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress014.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress015.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress016.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress017.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress019.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress020.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress021.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress022.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress023.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress024.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress025.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress026.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress027.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress028.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress029.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress030.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress031.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress032.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress033.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress034.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress035.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress036.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress037.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress038.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress039.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress040.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress041.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress042.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress043.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress044.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress045.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress046.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress047.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress048.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress049.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress050.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress051.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress052.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress053.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress054.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress055.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress056.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress057.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress058.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress059.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress060.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress061.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress062.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress063.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress064.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress065.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress066.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress067.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress068.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress069.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress070.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress071.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress072.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress073.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress074.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress076.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress077.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress078.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress080.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress081.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress082.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress083.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress084.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress085.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress086.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress087.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress088.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress089.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress090.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress091.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress092.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress093.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress094.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress095.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress097.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress100.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress101.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress102.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress103.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress104.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress105.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress106.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress107.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress108.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress109.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress110.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress111.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress112.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress113.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress114.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress115.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress116.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress117.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress118.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress119.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress120.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress121.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress122.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress123.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress124.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress125.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress126.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress127.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress128.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress129.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress130.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress131.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress132.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress133.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress134.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress135.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress136.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress137.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress138.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress139.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress141.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress142.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress143.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress144.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress145.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress146.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress147.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress148.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress149.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress150.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress151.jpg
# Fashion_Product_Dataset/Dresses\Navy_Dresses\Old_Navy_Dress152.jpg
# ...
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group310.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group311.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group312.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group313.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group314.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group315.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group316.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group317.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group318.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group319.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group320.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group321.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group322.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group323.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group324.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group325.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group326.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group327.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group328.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group329.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group330.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group331.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group332.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group333.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group334.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group335.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group336.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group337.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group338.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group339.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group340.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group341.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group342.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group343.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group344.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group345.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group346.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group347.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group348.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group349.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group350.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group351.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group352.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group353.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group354.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group355.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group356.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group357.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group358.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group359.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group360.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group361.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group362.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group363.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group364.jpeg
# Fashion_Product_Dataset/Watches\NordStrom_Watches\NordStrom_Watches_Group365.jpeg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches01.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches03.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches04.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches05.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches06.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches07.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches08.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches09.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches10.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches11.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches12.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches13.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches14.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches15.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches16.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches17.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches18.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches19.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches20.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches22.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches23.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches24.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches25.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches26.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches27.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches28.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches29.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches30.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches31.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches32.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches33.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches34.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches35.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches36.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches37.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches38.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches39.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches40.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches41.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches42.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches43.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches44.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches45.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches46.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches47.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches48.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches49.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches50.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches51.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches52.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches54.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches55.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches56.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches57.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches58.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches59.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches60.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group1_Watches61.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches01.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches02.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches03.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches04.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches05.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches06.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches07.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches08.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches09.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches10.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches11.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches12.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches13.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches14.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches15.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches16.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches17.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches18.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches19.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches20.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches21.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches22.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches23.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches24.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches25.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches26.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches27.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches28.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches29.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches30.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches31.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches32.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches33.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches34.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches35.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches36.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches45.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches46.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches47.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches48.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches49.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches50.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches51.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches52.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches53.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches54.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches55.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches56.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches57.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches58.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches59.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches60.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches61.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches62.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches63.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches64.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches65.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches66.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches67.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches68.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group2_Watches69.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches01.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches02.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches03.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches04.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches05.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches06.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches07.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches08.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches09.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches10.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches11.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches12.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches13.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches14.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches15.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches16.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches17.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches18.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches19.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches20.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches21.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches22.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches23.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches24.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches25.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches26.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches27.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches28.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches29.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches30.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches31.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches32.jpg
# Fashion_Product_Dataset/Watches\Zumiez_Watches\Zumiez_Group3_Watches33.jpg
#
# Done

# %% [markdown]
# ### Dataset & DataLoader included Feature Vector

# %%
# Define the dataset
image_directory = 'Fashion_Products'  # Replace with the actual directory path
custom_dataset = CustomImageDataset(root_dir=image_directory, transform=image_transform, include_feature_vector=True)

# Define the DataLoader
batch_size = 64
data_loader = DataLoader(dataset=custom_dataset, batch_size=batch_size, shuffle=True)

# %%
dataset_size = len(custom_dataset)
print(f'Total number of images in the dataset: {dataset_size}')
# Out:
# Total number of images in the dataset: 10046

# %%
# Let's display a single image with label and feature vector
def show_image_with_info(image, label, feature_vector):
    plt.imshow(image.permute(1, 2, 0))  # Convert from (C, H, W) to (H, W, C) for displaying with matplotlib
    plt.title(f"Label: {label}\nFeature Vector: {feature_vector}")
    plt.axis('off')
    plt.show()

# Get a batch from the DataLoader (assuming batch size is 1)
for labels, images, _, feature_vectors in data_loader:
    # Show the first image along with its label and feature vector
    show_image_with_info(images[0], labels[0], feature_vectors[0])
    break  # Break after showing the first batch
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
flattened_embedding= feature_vectors[0].flatten().reshape(1, -1)
flattened_embedding = flattened_embedding.reshape(-1, 1)
if flattened_embedding.ndim == 2:
    print("Array is 2D")
else:
    print("Array is not 2D")
# Out:
# Array is 2D

# %% [markdown]
# ### PCA

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def plot_scatter(feature_vectors, labels):
    pca = PCA(n_components=10)
    reduced_features = pca.fit_transform(feature_vectors)

    plt.figure(figsize=(10, 8))
    for label in set(labels):
        indices = [i for i, l in enumerate(labels) if l == label]
        plt.scatter(reduced_features[indices, 0], reduced_features[indices, 1], label=label)

    plt.title('Scatter Plot of Images based on Feature Vectors (PCA)')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend()
    plt.show()

plot_scatter(feature_vectors.numpy(), labels)

# %% [markdown]
# ### Apply KNN for computing image similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
def find_k_nearest_neighbors(query_index, feature_vectors, images, labels, K=5):
    # Extract the feature vector of the query image
    query_vector = feature_vectors[query_index].reshape(1, -1)

    # Calculate cosine similarity
    similarities = cosine_similarity(query_vector, feature_vectors)

    # Find the K-nearest neighbors for the query image
    indices = similarities.argsort()[0][-K:][::-1]
    distances = similarities[0, indices]

    # Plot the query image
    plt.figure(figsize=(3, 3))
    plt.imshow(images[query_index].permute(1, 2, 0))  # Assuming images is a tensor with shape [20, 3, 224, 224]
    plt.title(f"Query Image - {labels[query_index]}")
    plt.axis('off')
    plt.show()

    # Plot the K-nearest neighbors
    plt.figure(figsize=(15, 5))
    for i in range(K):
        plt.subplot(1, K, i + 1)
        plt.imshow(images[indices[i]].permute(1, 2, 0))
        plt.title(f"Neighbor {i + 1}\n{labels[indices[i]]}\nSimilarity: {distances[i]:.2f}")
        plt.axis('off')
    plt.show()

query_index = 0

find_k_nearest_neighbors(query_index, feature_vectors, images, labels, K=5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import faiss

feature_vectors = []
for labels, images, _, _ in data_loader:
    outputs = model(images)
    feature_vectors.append(outputs.numpy())

# Concatenate the feature vectors into a single numpy array
feature_vectors = np.concatenate(feature_vectors)

# Normalize feature vectors (optional, but can improve consistency)
normalized_feature_vectors = feature_vectors / np.linalg.norm(feature_vectors, axis=1, keepdims=True)

# Build the FAISS index
index = faiss.IndexFlatIP(normalized_feature_vectors.shape[1])  # IndexFlatIP for inner product (cosine similarity)
index.add(normalized_feature_vectors)

# Example: Query for K-nearest neighbors
query_index = 0
query_vector = normalized_feature_vectors[query_index].reshape(1, -1)
K = 5  # Number of neighbors to retrieve

# Search for K-nearest neighbors
distances, indices = index.search(query_vector, K)

# Visualize the query image and its K-nearest neighbors
show_image_with_info(images[query_index], labels[query_index], normalized_feature_vectors[query_index])

for i in range(K):
    neighbor_index = indices[0][i]
    similarity = distances[0][i]
    show_image_with_info(images[neighbor_index], labels[neighbor_index], normalized_feature_vectors[neighbor_index])
    print(f"Similarity with query: {similarity}")
